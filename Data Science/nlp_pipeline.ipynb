# %% [markdown]
# # NLP Pipeline

# %% [markdown]
# ## Overview of pipeline
#
# ![Overview of NLP Pipeline](images/pipeline.png "Overview of NLP Pipeline")

# %% [markdown]
# ## Text Document

# %%
text = """Peaky Blinders is a British crime drama television series created by Steven Knight. Set in Birmingham, England, it follows the exploits of the Peaky Blinders crime gang in the direct aftermath of the First World War. The fictional gang is loosely based on a real urban youth gang of the same name who were active in the city from the 1890s to the 1910s. It features an ensemble cast led by Cillian Murphy, starring as Tommy Shelby, Helen McCrory as Elizabeth "Polly" Gray, Paul Anderson as Arthur Shelby and Joe Cole as John Shelby, the gang's senior members. Tom Hardy, Sam Neill, Annabelle Wallis, Iddo Goldberg, Charlotte Riley, Paddy Considine, Adrien Brody, Aidan Gillen, Anya Taylor-Joy, Sam Claflin, James Frecheville and Stephen Graham have recurring roles. It premiered on 12 September 2013, telecast on BBC Two until the fourth series (with repeats on BBC Four), then moved to BBC One for the fifth and sixth series. The fifth series premiered on BBC One on 25 August 2019 and finished on 22 September 2019. Netflix, under a deal with Weinstein Company and Endemol, acquired the rights to release the show in the United States and around the world. In January 2021, it was announced that series six would be the last, followed by a spinoff film. Series six was broadcast from 27 February 2022 to 3 April 2022."""
print(text)
# Out:
# Peaky Blinders is a British crime drama television series created by Steven Knight. Set in Birmingham, England, it follows the exploits of the Peaky Blinders crime gang in the direct aftermath of the First World War. The fictional gang is loosely based on a real urban youth gang of the same name who were active in the city from the 1890s to the 1910s. It features an ensemble cast led by Cillian Murphy, starring as Tommy Shelby, Helen McCrory as Elizabeth "Polly" Gray, Paul Anderson as Arthur Shelby and Joe Cole as John Shelby, the gang's senior members. Tom Hardy, Sam Neill, Annabelle Wallis, Iddo Goldberg, Charlotte Riley, Paddy Considine, Adrien Brody, Aidan Gillen, Anya Taylor-Joy, Sam Claflin, James Frecheville and Stephen Graham have recurring roles. It premiered on 12 September 2013, telecast on BBC Two until the fourth series (with repeats on BBC Four), then moved to BBC One for the fifth and sixth series. The fifth series premiered on BBC One on 25 August 2019 and finished on 22 September 2019. Netflix, under a deal with Weinstein Company and Endemol, acquired the rights to release the show in the United States and around the world. In January 2021, it was announced that series six would be the last, followed by a spinoff film. Series six was broadcast from 27 February 2022 to 3 April 2022.

# %% [markdown]
# ## Step 1: Segmentation

# %%
sentences = text.split(". ")
sentences
# Out:
# ['Peaky Blinders is a British crime drama television series created by Steven Knight',
#  'Set in Birmingham, England, it follows the exploits of the Peaky Blinders crime gang in the direct aftermath of the First World War',
#  'The fictional gang is loosely based on a real urban youth gang of the same name who were active in the city from the 1890s to the 1910s',
#  'It features an ensemble cast led by Cillian Murphy, starring as Tommy Shelby, Helen McCrory as Elizabeth "Polly" Gray, Paul Anderson as Arthur Shelby and Joe Cole as John Shelby, the gang\'s senior members',
#  'Tom Hardy, Sam Neill, Annabelle Wallis, Iddo Goldberg, Charlotte Riley, Paddy Considine, Adrien Brody, Aidan Gillen, Anya Taylor-Joy, Sam Claflin, James Frecheville and Stephen Graham have recurring roles',
#  'It premiered on 12 September 2013, telecast on BBC Two until the fourth series (with repeats on BBC Four), then moved to BBC One for the fifth and sixth series',
#  'The fifth series premiered on BBC One on 25 August 2019 and finished on 22 September 2019',
#  'Netflix, under a deal with Weinstein Company and Endemol, acquired the rights to release the show in the United States and around the world',
#  'In January 2021, it was announced that series six would be the last, followed by a spinoff film',
#  'Series six was broadcast from 27 February 2022 to 3 April 2022.']

# %% [markdown]
# ## Step 2: Tokenization

# %%
import nltk
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_ru is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package basque_grammars is already up-to-date!
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package biocreative_ppi is already up-to-date!
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package bllip_wsj_no_aux is already up-to-date!
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package book_grammars is already up-to-date!
# [nltk_data]    | Downloading package brown to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package brown_tei to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package brown_tei is already up-to-date!
# [nltk_data]    | Downloading package cess_cat to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cess_cat is already up-to-date!
# [nltk_data]    | Downloading package cess_esp to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cess_esp is already up-to-date!
# [nltk_data]    | Downloading package chat80 to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package chat80 is already up-to-date!
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package city_database is already up-to-date!
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package comparative_sentences is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package comtrans to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package comtrans is already up-to-date!
# [nltk_data]    | Downloading package conll2000 to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package conll2000 is already up-to-date!
# [nltk_data]    | Downloading package conll2002 to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package conll2002 is already up-to-date!
# [nltk_data]    | Downloading package conll2007 to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package conll2007 is already up-to-date!
# [nltk_data]    | Downloading package crubadan to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package crubadan is already up-to-date!
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package dependency_treebank is already up-to-date!
# [nltk_data]    | Downloading package dolch to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package dolch is already up-to-date!
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package europarl_raw is already up-to-date!
# [nltk_data]    | Downloading package extended_omw to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package extended_omw is already up-to-date!
# [nltk_data]    | Downloading package floresta to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package floresta is already up-to-date!
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package framenet_v15 is already up-to-date!
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package framenet_v17 is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package ieer to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ieer is already up-to-date!
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package indian to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package indian is already up-to-date!
# [nltk_data]    | Downloading package jeita to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package jeita is already up-to-date!
# [nltk_data]    | Downloading package kimmo to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package kimmo is already up-to-date!
# [nltk_data]    | Downloading package knbc to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package knbc is already up-to-date!
# [nltk_data]    | Downloading package large_grammars to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package large_grammars is already up-to-date!
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package lin_thesaurus is already up-to-date!
# [nltk_data]    | Downloading package mac_morpho to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package mac_morpho is already up-to-date!
# [nltk_data]    | Downloading package machado to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package machado is already up-to-date!
# [nltk_data]    | Downloading package masc_tagged to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package masc_tagged is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_treebank_pos_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package moses_sample to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package moses_sample is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package mte_teip5 to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package mte_teip5 is already up-to-date!
# [nltk_data]    | Downloading package mwa_ppdb to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package mwa_ppdb is already up-to-date!
# [nltk_data]    | Downloading package names to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package nombank.1.0 to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package nombank.1.0 is already up-to-date!
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package nonbreaking_prefixes is already up-to-date!
# [nltk_data]    | Downloading package nps_chat to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package nps_chat is already up-to-date!
# [nltk_data]    | Downloading package omw to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package omw-1.4 to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package omw-1.4 is already up-to-date!
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package opinion_lexicon is already up-to-date!
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package panlex_swadesh is already up-to-date!
# [nltk_data]    | Downloading package paradigms to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package paradigms is already up-to-date!
# [nltk_data]    | Downloading package pe08 to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pe08 is already up-to-date!
# [nltk_data]    | Downloading package perluniprops to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package perluniprops is already up-to-date!
# [nltk_data]    | Downloading package pil to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pil is already up-to-date!
# [nltk_data]    | Downloading package pl196x to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pl196x is already up-to-date!
# [nltk_data]    | Downloading package porter_test to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package porter_test is already up-to-date!
# [nltk_data]    | Downloading package ppattach to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ppattach is already up-to-date!
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package problem_reports is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package product_reviews_1 is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package product_reviews_2 is already up-to-date!
# [nltk_data]    | Downloading package propbank to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package propbank is already up-to-date!
# [nltk_data]    | Downloading package pros_cons to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pros_cons is already up-to-date!
# [nltk_data]    | Downloading package ptb to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ptb is already up-to-date!
# [nltk_data]    | Downloading package punkt to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package qc to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package qc is already up-to-date!
# [nltk_data]    | Downloading package reuters to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package reuters is already up-to-date!
# [nltk_data]    | Downloading package rslp to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package rslp is already up-to-date!
# [nltk_data]    | Downloading package rte to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package rte is already up-to-date!
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sample_grammars is already up-to-date!
# [nltk_data]    | Downloading package semcor to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package semcor is already up-to-date!
# [nltk_data]    | Downloading package senseval to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package senseval is already up-to-date!
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sentence_polarity is already up-to-date!
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sentiwordnet is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sinica_treebank is already up-to-date!
# [nltk_data]    | Downloading package smultron to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package smultron is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package spanish_grammars is already up-to-date!
# [nltk_data]    | Downloading package state_union to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package state_union is already up-to-date!
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package subjectivity is already up-to-date!
# [nltk_data]    | Downloading package swadesh to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package swadesh is already up-to-date!
# [nltk_data]    | Downloading package switchboard to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package switchboard is already up-to-date!
# [nltk_data]    | Downloading package tagsets to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package tagsets is already up-to-date!
# [nltk_data]    | Downloading package timit to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package timit is already up-to-date!
# [nltk_data]    | Downloading package toolbox to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package toolbox is already up-to-date!
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package udhr to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package udhr is already up-to-date!
# [nltk_data]    | Downloading package udhr2 to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package udhr2 is already up-to-date!
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package unicode_samples is already up-to-date!
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package universal_tagset is already up-to-date!
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package universal_treebanks_v20 is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package vader_lexicon to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package vader_lexicon is already up-to-date!
# [nltk_data]    | Downloading package verbnet to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package verbnet is already up-to-date!
# [nltk_data]    | Downloading package verbnet3 to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package verbnet3 is already up-to-date!
# [nltk_data]    | Downloading package webtext to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package webtext is already up-to-date!
# [nltk_data]    | Downloading package wmt15_eval to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wmt15_eval is already up-to-date!
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package word2vec_sample is already up-to-date!
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet2021 to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet2021 is already up-to-date!
# [nltk_data]    | Downloading package wordnet31 to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet31 is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package ycoe to
# [nltk_data]    |     C:\Users\saile\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ycoe is already up-to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection all
# True

# %%
from nltk.tokenize import word_tokenize

words = []
for sentence in sentences:
    sentence_words = word_tokenize(sentence)
    words.append(sentence_words)

print(words)
# Out:
# [['Peaky', 'Blinders', 'is', 'a', 'British', 'crime', 'drama', 'television', 'series', 'created', 'by', 'Steven', 'Knight'], ['Set', 'in', 'Birmingham', ',', 'England', ',', 'it', 'follows', 'the', 'exploits', 'of', 'the', 'Peaky', 'Blinders', 'crime', 'gang', 'in', 'the', 'direct', 'aftermath', 'of', 'the', 'First', 'World', 'War'], ['The', 'fictional', 'gang', 'is', 'loosely', 'based', 'on', 'a', 'real', 'urban', 'youth', 'gang', 'of', 'the', 'same', 'name', 'who', 'were', 'active', 'in', 'the', 'city', 'from', 'the', '1890s', 'to', 'the', '1910s'], ['It', 'features', 'an', 'ensemble', 'cast', 'led', 'by', 'Cillian', 'Murphy', ',', 'starring', 'as', 'Tommy', 'Shelby', ',', 'Helen', 'McCrory', 'as', 'Elizabeth', '``', 'Polly', "''", 'Gray', ',', 'Paul', 'Anderson', 'as', 'Arthur', 'Shelby', 'and', 'Joe', 'Cole', 'as', 'John', 'Shelby', ',', 'the', 'gang', "'s", 'senior', 'members'], ['Tom', 'Hardy', ',', 'Sam', 'Neill', ',', 'Annabelle', 'Wallis', ',', 'Iddo', 'Goldberg', ',', 'Charlotte', 'Riley', ',', 'Paddy', 'Considine', ',', 'Adrien', 'Brody', ',', 'Aidan', 'Gillen', ',', 'Anya', 'Taylor-Joy', ',', 'Sam', 'Claflin', ',', 'James', 'Frecheville', 'and', 'Stephen', 'Graham', 'have', 'recurring', 'roles'], ['It', 'premiered', 'on', '12', 'September', '2013', ',', 'telecast', 'on', 'BBC', 'Two', 'until', 'the', 'fourth', 'series', '(', 'with', 'repeats', 'on', 'BBC', 'Four', ')', ',', 'then', 'moved', 'to', 'BBC', 'One', 'for', 'the', 'fifth', 'and', 'sixth', 'series'], ['The', 'fifth', 'series', 'premiered', 'on', 'BBC', 'One', 'on', '25', 'August', '2019', 'and', 'finished', 'on', '22', 'September', '2019'], ['Netflix', ',', 'under', 'a', 'deal', 'with', 'Weinstein', 'Company', 'and', 'Endemol', ',', 'acquired', 'the', 'rights', 'to', 'release', 'the', 'show', 'in', 'the', 'United', 'States', 'and', 'around', 'the', 'world'], ['In', 'January', '2021', ',', 'it', 'was', 'announced', 'that', 'series', 'six', 'would', 'be', 'the', 'last', ',', 'followed', 'by', 'a', 'spinoff', 'film'], ['Series', 'six', 'was', 'broadcast', 'from', '27', 'February', '2022', 'to', '3', 'April', '2022', '.']]

# %% [markdown]
# ## Step 3: Parts of Speech Tagging

# %%
pos_tags = []
for sentence in words:
    pos_tags.append(nltk.pos_tag(sentence))
                    
print(pos_tags)
# Out:
# [[('Peaky', 'NNP'), ('Blinders', 'NNP'), ('is', 'VBZ'), ('a', 'DT'), ('British', 'JJ'), ('crime', 'NN'), ('drama', 'NN'), ('television', 'NN'), ('series', 'NN'), ('created', 'VBN'), ('by', 'IN'), ('Steven', 'NNP'), ('Knight', 'NNP')], [('Set', 'NNP'), ('in', 'IN'), ('Birmingham', 'NNP'), (',', ','), ('England', 'NNP'), (',', ','), ('it', 'PRP'), ('follows', 'VBZ'), ('the', 'DT'), ('exploits', 'NNS'), ('of', 'IN'), ('the', 'DT'), ('Peaky', 'NNP'), ('Blinders', 'NNP'), ('crime', 'NN'), ('gang', 'NN'), ('in', 'IN'), ('the', 'DT'), ('direct', 'JJ'), ('aftermath', 'NN'), ('of', 'IN'), ('the', 'DT'), ('First', 'NNP'), ('World', 'NNP'), ('War', 'NNP')], [('The', 'DT'), ('fictional', 'JJ'), ('gang', 'NN'), ('is', 'VBZ'), ('loosely', 'RB'), ('based', 'VBN'), ('on', 'IN'), ('a', 'DT'), ('real', 'JJ'), ('urban', 'JJ'), ('youth', 'NN'), ('gang', 'NN'), ('of', 'IN'), ('the', 'DT'), ('same', 'JJ'), ('name', 'NN'), ('who', 'WP'), ('were', 'VBD'), ('active', 'JJ'), ('in', 'IN'), ('the', 'DT'), ('city', 'NN'), ('from', 'IN'), ('the', 'DT'), ('1890s', 'CD'), ('to', 'TO'), ('the', 'DT'), ('1910s', 'NNS')], [('It', 'PRP'), ('features', 'VBZ'), ('an', 'DT'), ('ensemble', 'JJ'), ('cast', 'NN'), ('led', 'VBN'), ('by', 'IN'), ('Cillian', 'JJ'), ('Murphy', 'NNP'), (',', ','), ('starring', 'VBG'), ('as', 'IN'), ('Tommy', 'NNP'), ('Shelby', 'NNP'), (',', ','), ('Helen', 'NNP'), ('McCrory', 'NNP'), ('as', 'IN'), ('Elizabeth', 'NNP'), ('``', '``'), ('Polly', 'NNP'), ("''", "''"), ('Gray', 'NNP'), (',', ','), ('Paul', 'NNP'), ('Anderson', 'NNP'), ('as', 'IN'), ('Arthur', 'NNP'), ('Shelby', 'NNP'), ('and', 'CC'), ('Joe', 'NNP'), ('Cole', 'NNP'), ('as', 'IN'), ('John', 'NNP'), ('Shelby', 'NNP'), (',', ','), ('the', 'DT'), ('gang', 'NN'), ("'s", 'POS'), ('senior', 'JJ'), ('members', 'NNS')], [('Tom', 'NNP'), ('Hardy', 'NNP'), (',', ','), ('Sam', 'NNP'), ('Neill', 'NNP'), (',', ','), ('Annabelle', 'NNP'), ('Wallis', 'NNP'), (',', ','), ('Iddo', 'NNP'), ('Goldberg', 'NNP'), (',', ','), ('Charlotte', 'NNP'), ('Riley', 'NNP'), (',', ','), ('Paddy', 'NNP'), ('Considine', 'NNP'), (',', ','), ('Adrien', 'NNP'), ('Brody', 'NNP'), (',', ','), ('Aidan', 'NNP'), ('Gillen', 'NNP'), (',', ','), ('Anya', 'NNP'), ('Taylor-Joy', 'NNP'), (',', ','), ('Sam', 'NNP'), ('Claflin', 'NNP'), (',', ','), ('James', 'NNP'), ('Frecheville', 'NNP'), ('and', 'CC'), ('Stephen', 'NNP'), ('Graham', 'NNP'), ('have', 'VBP'), ('recurring', 'VBG'), ('roles', 'NNS')], [('It', 'PRP'), ('premiered', 'VBD'), ('on', 'IN'), ('12', 'CD'), ('September', 'NNP'), ('2013', 'CD'), (',', ','), ('telecast', 'NN'), ('on', 'IN'), ('BBC', 'NNP'), ('Two', 'CD'), ('until', 'IN'), ('the', 'DT'), ('fourth', 'JJ'), ('series', 'NN'), ('(', '('), ('with', 'IN'), ('repeats', 'NNS'), ('on', 'IN'), ('BBC', 'NNP'), ('Four', 'NNP'), (')', ')'), (',', ','), ('then', 'RB'), ('moved', 'VBD'), ('to', 'TO'), ('BBC', 'NNP'), ('One', 'NNP'), ('for', 'IN'), ('the', 'DT'), ('fifth', 'NN'), ('and', 'CC'), ('sixth', 'JJ'), ('series', 'NN')], [('The', 'DT'), ('fifth', 'JJ'), ('series', 'NN'), ('premiered', 'VBN'), ('on', 'IN'), ('BBC', 'NNP'), ('One', 'NNP'), ('on', 'IN'), ('25', 'CD'), ('August', 'NNP'), ('2019', 'CD'), ('and', 'CC'), ('finished', 'VBD'), ('on', 'IN'), ('22', 'CD'), ('September', 'NNP'), ('2019', 'CD')], [('Netflix', 'NNP'), (',', ','), ('under', 'IN'), ('a', 'DT'), ('deal', 'NN'), ('with', 'IN'), ('Weinstein', 'NNP'), ('Company', 'NNP'), ('and', 'CC'), ('Endemol', 'NNP'), (',', ','), ('acquired', 'VBD'), ('the', 'DT'), ('rights', 'NNS'), ('to', 'TO'), ('release', 'VB'), ('the', 'DT'), ('show', 'NN'), ('in', 'IN'), ('the', 'DT'), ('United', 'NNP'), ('States', 'NNPS'), ('and', 'CC'), ('around', 'IN'), ('the', 'DT'), ('world', 'NN')], [('In', 'IN'), ('January', 'NNP'), ('2021', 'CD'), (',', ','), ('it', 'PRP'), ('was', 'VBD'), ('announced', 'VBN'), ('that', 'IN'), ('series', 'NN'), ('six', 'CD'), ('would', 'MD'), ('be', 'VB'), ('the', 'DT'), ('last', 'JJ'), (',', ','), ('followed', 'VBN'), ('by', 'IN'), ('a', 'DT'), ('s ...

# %% [markdown]
# ## Step 4: Text Lemmatization

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

# check all the unique tag values so that a mapping can be created from the pos tags to a wordnet type
tag_values = []
for lis in pos_tags:
    for tag in lis:
        tag_values.append(tag[1])

unique_tag_values = list(set(tag_values))
print(unique_tag_values)
# Out:
# ['VBG', 'POS', 'CC', 'IN', 'NN', 'VBD', 'CD', 'WP', 'NNP', 'VB', "''", '(', 'JJ', 'VBN', 'NNPS', '.', 'TO', 'VBP', 'VBZ', 'NNS', 'MD', ')', 'DT', ',', 'RB', 'PRP', '``']

# %%
# mapping
from nltk.corpus.reader.wordnet import ADJ, ADV, NOUN, VERB

pos_tag_map = {
    'VBG': VERB,
    'NN': NOUN,
    'VBD': VERB,
    'JJ': ADJ,
    'VBP': VERB,
    'VBZ': VERB,
    'RB': ADV
}

lemmatized_words = []
for lis in pos_tags:
    temp = []
    for tag_tuple in lis:
        word = tag_tuple[0]
        tag = tag_tuple[1]
        if pos_tag_map.get(tag) == None:
            temp.append(word)
        else:
            temp.append(lemmatizer.lemmatize(word, pos_tag_map[tag]))
    lemmatized_words.append(temp)

temp = []
for lis in lemmatized_words:
    temp.extend(lis)
    temp.append('.')
    
lemmatized_words = temp[:-1]
print(lemmatized_words)
# Out:
# ['Peaky', 'Blinders', 'be', 'a', 'British', 'crime', 'drama', 'television', 'series', 'created', 'by', 'Steven', 'Knight', '.', 'Set', 'in', 'Birmingham', ',', 'England', ',', 'it', 'follow', 'the', 'exploits', 'of', 'the', 'Peaky', 'Blinders', 'crime', 'gang', 'in', 'the', 'direct', 'aftermath', 'of', 'the', 'First', 'World', 'War', '.', 'The', 'fictional', 'gang', 'be', 'loosely', 'based', 'on', 'a', 'real', 'urban', 'youth', 'gang', 'of', 'the', 'same', 'name', 'who', 'be', 'active', 'in', 'the', 'city', 'from', 'the', '1890s', 'to', 'the', '1910s', '.', 'It', 'feature', 'an', 'ensemble', 'cast', 'led', 'by', 'Cillian', 'Murphy', ',', 'star', 'as', 'Tommy', 'Shelby', ',', 'Helen', 'McCrory', 'as', 'Elizabeth', '``', 'Polly', "''", 'Gray', ',', 'Paul', 'Anderson', 'as', 'Arthur', 'Shelby', 'and', 'Joe', 'Cole', 'as', 'John', 'Shelby', ',', 'the', 'gang', "'s", 'senior', 'members', '.', 'Tom', 'Hardy', ',', 'Sam', 'Neill', ',', 'Annabelle', 'Wallis', ',', 'Iddo', 'Goldberg', ',', 'Charlotte', 'Riley', ',', 'Paddy', 'Considine', ',', 'Adrien', 'Brody', ',', 'Aidan', 'Gillen', ',', 'Anya', 'Taylor-Joy', ',', 'Sam', 'Claflin', ',', 'James', 'Frecheville', 'and', 'Stephen', 'Graham', 'have', 'recur', 'roles', '.', 'It', 'premier', 'on', '12', 'September', '2013', ',', 'telecast', 'on', 'BBC', 'Two', 'until', 'the', 'fourth', 'series', '(', 'with', 'repeats', 'on', 'BBC', 'Four', ')', ',', 'then', 'move', 'to', 'BBC', 'One', 'for', 'the', 'fifth', 'and', 'sixth', 'series', '.', 'The', 'fifth', 'series', 'premiered', 'on', 'BBC', 'One', 'on', '25', 'August', '2019', 'and', 'finish', 'on', '22', 'September', '2019', '.', 'Netflix', ',', 'under', 'a', 'deal', 'with', 'Weinstein', 'Company', 'and', 'Endemol', ',', 'acquire', 'the', 'rights', 'to', 'release', 'the', 'show', 'in', 'the', 'United', 'States', 'and', 'around', 'the', 'world', '.', 'In', 'January', '2021', ',', 'it', 'be', 'announced', 'that', 'series', 'six', 'would', 'be', 'the', 'last', ',', 'followed', 'by', 'a', 'spinoff', 'film', '.', 'Series', 'six', 'be', 'broadcast', 'from', '27', 'February', '2022', 'to', '3', 'April', '2022', '.']

# %% [markdown]
# ## Step 5: Identifying stop words

# %%
from nltk.corpus import stopwords

stop_words = set(stopwords.words('english'))

filtered_paragraph = []

for word in lemmatized_words:
    if (word not in stop_words):
        filtered_paragraph.append(word)

print(filtered_paragraph)
# Out:
# ['Peaky', 'Blinders', 'British', 'crime', 'drama', 'television', 'series', 'created', 'Steven', 'Knight', '.', 'Set', 'Birmingham', ',', 'England', ',', 'follow', 'exploits', 'Peaky', 'Blinders', 'crime', 'gang', 'direct', 'aftermath', 'First', 'World', 'War', '.', 'The', 'fictional', 'gang', 'loosely', 'based', 'real', 'urban', 'youth', 'gang', 'name', 'active', 'city', '1890s', '1910s', '.', 'It', 'feature', 'ensemble', 'cast', 'led', 'Cillian', 'Murphy', ',', 'star', 'Tommy', 'Shelby', ',', 'Helen', 'McCrory', 'Elizabeth', '``', 'Polly', "''", 'Gray', ',', 'Paul', 'Anderson', 'Arthur', 'Shelby', 'Joe', 'Cole', 'John', 'Shelby', ',', 'gang', "'s", 'senior', 'members', '.', 'Tom', 'Hardy', ',', 'Sam', 'Neill', ',', 'Annabelle', 'Wallis', ',', 'Iddo', 'Goldberg', ',', 'Charlotte', 'Riley', ',', 'Paddy', 'Considine', ',', 'Adrien', 'Brody', ',', 'Aidan', 'Gillen', ',', 'Anya', 'Taylor-Joy', ',', 'Sam', 'Claflin', ',', 'James', 'Frecheville', 'Stephen', 'Graham', 'recur', 'roles', '.', 'It', 'premier', '12', 'September', '2013', ',', 'telecast', 'BBC', 'Two', 'fourth', 'series', '(', 'repeats', 'BBC', 'Four', ')', ',', 'move', 'BBC', 'One', 'fifth', 'sixth', 'series', '.', 'The', 'fifth', 'series', 'premiered', 'BBC', 'One', '25', 'August', '2019', 'finish', '22', 'September', '2019', '.', 'Netflix', ',', 'deal', 'Weinstein', 'Company', 'Endemol', ',', 'acquire', 'rights', 'release', 'show', 'United', 'States', 'around', 'world', '.', 'In', 'January', '2021', ',', 'announced', 'series', 'six', 'would', 'last', ',', 'followed', 'spinoff', 'film', '.', 'Series', 'six', 'broadcast', '27', 'February', '2022', '3', 'April', '2022', '.']

# %% [markdown]
# ## Step 6: Dependency Parsing

# %%
import spacy
from spacy import displacy

nlp = spacy.load('en_core_web_sm')

doc = nlp(' '.join(filtered_paragraph))
displacy.render(doc, jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="e60039218bd748bb8a47900633227cf6-0" class="displacy" width="27875" height="1187.0" direction="ltr" style="max-width: none; height: 1187.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Peaky</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">Blinders</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">British</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">crime</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">drama</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">television</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">series</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">created</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">Steven</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">Knight .</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">Set</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">Birmingham ,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">England ,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">follow</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">exploits</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">Peaky</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">Blinders</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">crime</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">gang</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">direct</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">aftermath</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">First</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">World</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">War .</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">fictional</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">gang</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">loosely</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">based</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">real</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="cur

# %% [markdown]
# ## Step 7: Named entity recognition

# %%
for word in doc.ents:
    print(word.text, word.label_)
# Out:
# Peaky Blinders PERSON
# British NORP
# Steven Knight PERSON
# Set Birmingham PERSON
# England GPE
# Peaky Blinders PERSON
# First World War EVENT
# 1890s 1910s DATE
# Cillian Murphy PERSON
# Tommy Shelby PERSON
# Helen McCrory Elizabeth PERSON
# Paul Anderson PERSON
# John Shelby PERSON
# Tom Hardy PERSON
# Sam Neill PERSON
# Annabelle Wallis PERSON
# Iddo Goldberg PERSON
# Charlotte Riley PERSON
# Paddy Considine ORG
# Adrien Brody PERSON
# Aidan Gillen PERSON
# Anya Taylor-Joy PERSON
# Sam Claflin PERSON
# James Frecheville PERSON
# Stephen Graham PERSON
# 12 September 2013 DATE
# BBC ORG
# Two fourth series DATE
# BBC ORG
# Four CARDINAL
# BBC ORG
# sixth ORDINAL
# fifth ORDINAL
# BBC ORG
# August 2019 DATE
# September 2019 DATE
# Weinstein Company Endemol PERSON
# United States GPE
# January 2021 DATE
# six CARDINAL
# six CARDINAL
# February 2022 DATE
# 3 April 2022 DATE

# %%
# !pip install neuralcoref

import neuralcoref

newnlp = spacy.load('en_core_web_lg')
neuralcoref.add_to_pipe(newnlp)
# Out:
# Collecting neuralcoref
#   Using cached neuralcoref-4.0.tar.gz (368 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: numpy>=1.15.0 in c:\users\saile\documents\sailesh\work\cognizant\training\hands on\venv\lib\site-packages (from neuralcoref) (1.22.3)
# Requirement already satisfied: boto3 in c:\users\saile\documents\sailesh\work\cognizant\training\hands on\venv\lib\site-packages (from neuralcoref) (1.21.40)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\saile\documents\sailesh\work\cognizant\training\hands on\venv\lib\site-packages (from neuralcoref) (2.27.1)
# Requirement already satisfied: spacy>=2.1.0 in c:\users\saile\documents\sailesh\work\cognizant\training\hands on\venv\lib\site-packages (from neuralcoref) (3.2.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\saile\documents\sailesh\work\cognizant\training\hands on\venv\lib\site-packages (from requests<3.0.0,>=2.13.0->neuralcoref) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\saile\documents\sailesh\work\cognizant\training\hands on\venv\lib\site-packages (from requests<3.0.0,>=2.13.0->neuralcoref) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\saile\documents\sailesh\work\cognizant\training\hands on\venv\lib\site-packages (from requests<3.0.0,>=2.13.0->neuralcoref) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\saile\documents\sailesh\work\cognizant\training\hands on\venv\lib\site-packages (from requests<3.0.0,>=2.13.0->neuralcoref) (3.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in c:\users\saile\documents\sailesh\work\cognizant\training\hands on\venv\lib\site-packages (from spacy>=2.1.0->neuralcoref) (0.9.1)
# Requirement already satisfied: jinja2 in c:\users\saile\documents\sailesh\work\cognizant\training\hands on\venv\lib\site-packages (from spacy>=2.1.0->neuralcoref) (3.1.1)
# Requirement already satisfied: setuptools in c:\users\saile\documents\sailesh\work\cognizant\training\hands on\venv\lib\site-packages (from spacy>=2.1.0->neuralcoref) (58.1.0)
# Requirement already satisfied: click<8.1.0 in c:\users\saile\documents\sailesh\work\cognizant\training\hands on\venv\lib\site-packages (from spacy>=2.1.0->neuralcoref) (8.0.4)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\saile\documents\sailesh\work\cognizant\training\hands on\venv\lib\site-packages (from spacy>=2.1.0->neuralcoref) (3.3.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\saile\documents\sailesh\work\cognizant\training\hands on\venv\lib\site-packages (from spacy>=2.1.0->neuralcoref) (2.0.7)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in c:\users\saile\documents\sailesh\work\cognizant\training\hands on\venv\lib\site-packages (from spacy>=2.1.0->neuralcoref) (1.8.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\saile\documents\sailesh\work\cognizant\training\hands on\venv\lib\site-packages (from spacy>=2.1.0->neuralcoref) (1.0.6)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\saile\documents\sailesh\work\cognizant\training\hands on\venv\lib\site-packages (from spacy>=2.1.0->neuralcoref) (0.7.7)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\saile\documents\sailesh\work\cognizant\training\hands on\venv\lib\site-packages (from spacy>=2.1.0->neuralcoref) (0.6.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\saile\documents\sailesh\work\cognizant\training\hands on\venv\lib\site-packages (from spacy>=2.1.0->neuralcoref) (4.64.0)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in c:\users\saile\documents\sailesh\work\cognizant\training\hands on\venv\lib\site-packages (from spacy>=2.1.0->neuralcoref) (0.4.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\saile\documents\sailesh\work\cognizant\training\hands on\venv\lib\site-packages (from spacy>=2.1.0->neuralcoref) (21.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\saile\documents\sailesh\work\cognizant\training\hands on\venv\lib\site-packages (from spacy>=2.1.0->neuralcoref) (2.0.6)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\saile\documents\sailesh\work\cognizant\training\hands on\venv\lib\site-packages (from spacy>=2.1.0->neuralcoref) (1.0.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in c:\users\saile\documents\sailesh\work\cognizant\training\hands on\venv\lib\site-packages (from spacy>=2.1.0->neuralcoref) (2.4.2)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in c:\users\saile\documents\sailesh\work\cognizant\training\hands on\venv\lib\site-packages (from spacy>=2.1.0->neuralcoref) (8.0.15)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in c:\users\saile\documents\sailesh\work\cognizant\training\hands on\venv\lib\site-packages (from spacy>=2.1.0->neuralcoref) (3.0.9)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\saile\documents\sailesh\work\cognizant\training\hands on\venv\lib\site-packages (from spacy>=2.1.0->neuralcoref) (3.0.6)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\saile\documents\sailesh\work\cognizant\training\hands on\venv\lib\site-packages (from boto3->neuralcoref) (1.0.0)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in c:\users\saile\documents\sailesh\work\cognizant\training\hands on\venv\lib\site-packages (from boto3->neuralcoref) (0.5.2)
# Requirement already satisfied: botocore<1.25.0,>=1.24.40 in c:\users\saile\documents\sailesh\work\cognizant\training\hands on\venv\lib\site-packages (from boto3->neuralcoref) (1.24.40)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\saile\documents\sailesh\work\cognizant\training\hands on\venv\lib\site-packages (from botocore<1.25.0,>=1.24.40->boto3->neuralcoref) (2.8.2)
# Requirement already satisfied: colorama in c:\users\saile\documents\sailesh\work\cognizant\training\hands on\venv\lib\site-packages (from click<8.1.0->spacy>=2.1.0->neuralcoref) (0.4.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\saile\documents\sailesh\work\cognizant\training\hands on\venv\lib\site-packages (from packaging>=20.0->spacy>=2.1.0->neuralcoref) (3.0.7)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in c:\users\saile\documents\sailesh\work\cognizant\training\hands on\venv\lib\site-packages (from pathy>=0.3.5->spacy>=2.1.0->neuralcoref) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\saile\documents\sailesh\work\cognizant\training\hands on\venv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy>=2.1.0->neuralcoref) (4.1.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\saile\documents\sailesh\work\cognizant\training\hands on\venv\lib\site-packages (from jinja2->spacy>=2.1.0->neuralcoref) (2.1.1)
# Requirement already satisfied: six>=1.5 in c:\users\saile\documents\sailesh\work\cognizant\training\hands on\venv\lib\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.25.0,>=1.24.40->boto3->neuralcoref) (1.16.0)
# Building wheels for collected packages: neuralcoref
#   Building wheel for neuralcoref (setup.py): started
#   Building wheel for neuralcoref (setup.py): finished with status 'error'
#   Running setup.py clean for neuralcoref
# Failed to build neuralcoref
# Installing collected packages: neuralcoref
#   Running setup.py install for neuralcoref: started
#   Running setup.py install for neuralcoref: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [114 lines of output]
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-3.10
#   creating build\lib.win-amd64-3.10\neuralcoref
#   copying neuralcoref\file_utils.py -> build\lib.win-amd64-3.10\neuralcoref
#   copying neuralcoref\__init__.py -> build\lib.win-amd64-3.10\neuralcoref
#   creating build\lib.win-amd64-3.10\neuralcoref\tests
#   copying neuralcoref\tests\test_neuralcoref.py -> build\lib.win-amd64-3.10\neuralcoref\tests
#   copying neuralcoref\tests\__init__.py -> build\lib.win-amd64-3.10\neuralcoref\tests
#   creating build\lib.win-amd64-3.10\neuralcoref\train
#   copying neuralcoref\train\algorithm.py -> build\lib.win-amd64-3.10\neuralcoref\train
#   copying neuralcoref\train\compat.py -> build\lib.win-amd64-3.10\neuralcoref\train
#   copying neuralcoref\train\conllparser.py -> build\lib.win-amd64-3.10\neuralcoref\train
#   copying neuralcoref\train\dataset.py -> build\lib.win-amd64-3.10\neuralcoref\train
#   copying neuralcoref\train\document.py -> build\lib.win-amd64-3.10\neuralcoref\train
#   copying neuralcoref\train\evaluator.py -> build\lib.win-amd64-3.10\neuralcoref\train
#   copying neuralcoref\train\learn.py -> build\lib.win-amd64-3.10\neuralcoref\train
#   copying neuralcoref\train\model.py -> build\lib.win-amd64-3.10\neuralcoref\train
#   copying neuralcoref\train\utils.py -> build\lib.win-amd64-3.10\neuralcoref\train
#   copying neuralcoref\train\__init__.py -> build\lib.win-amd64-3.10\neuralcoref\train
#   running build_ext
#   building 'neuralcoref.neuralcoref' extension
#   creating build\temp.win-amd64-3.10
#   creating build\temp.win-amd64-3.10\Release
#   creating build\temp.win-amd64-3.10\Release\neuralcoref
#   C:\Program Files\Microsoft Visual Studio\2022\Community\VC\Tools\MSVC\14.31.31103\bin\HostX86\x64\cl.exe /c /nologo /Ox /W3 /GL /DNDEBUG /MD -IC:\Users\saile\AppData\Local\Programs\Python\Python310\include -IC:\Users\saile\AppData\Local\Temp\pip-install-5zugghos\neuralcoref_9fbdf1ae57be4cdc9bb2addfd06aecbe\include -IC:\users\saile\Documents\sailesh\Work\Cognizant\Training\Hands On\venv\include -IC:\Users\saile\AppData\Local\Programs\Python\Python310\include -IC:\Users\saile\AppData\Local\Programs\Python\Python310\Include -IC:\Program Files\Microsoft Visual Studio\2022\Community\VC\Tools\MSVC\14.31.31103\include -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.19041.0\\shared -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.19041.0\\um -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.19041.0\\winrt -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.19041.0\\cppwinrt /EHsc /Tpneuralcoref/neuralcoref.cpp /Fobuild\temp.win-amd64-3.10\Release\neuralcoref/neuralcoref.obj /Ox /EHsc
#   neuralcoref.cpp
#   C:\Users\saile\AppData\Local\Temp\pip-install-5zugghos\neuralcoref_9fbdf1ae57be4cdc9bb2addfd06aecbe\include\numpy\npy_deprecated_api.h(8) : Warning Msg: Using deprecated NumPy API, disable it by #defining NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION
#   neuralcoref/neuralcoref.cpp(6050): warning C4244: '=': conversion from 'Py_ssize_t' to 'int', possible loss of data
#   neuralcoref/neuralcoref.cpp(6904): warning C4244: '=': conversion from 'double' to 'float', possible loss of data
#   neuralcoref/neuralcoref.cpp(8989): warning C4018: '>': signed/unsigned mismatch
#   neuralcoref/neuralcoref.cpp(9046): warning C4018: '<': signed/unsigned mismatch
#   neuralcoref/neuralcoref.cpp(10177): warning C4244: '=': conversion from 'Py_ssize_t' to 'int', possible loss of data
#   neuralcoref/neuralcoref.cpp(10252): warning C4244: '=': conversion from 'Py_ssize_t' to 'int', possible loss of data
#   neuralcoref/neuralcoref.cpp(17150): warning C4244: '=': conversion from 'Py_ssize_t' to 'int', possible loss of data
#   neuralcoref/neuralcoref.cpp(18283): warning C4244: 'argument': conversion from 'uint64_t' to 'int', possible loss of data
#   neuralcoref/neuralcoref.cpp(18283): warning C4244: 'argument': conversion from 'uint64_t' to 'int', possible loss of data
#   neuralcoref/neuralcoref.cpp(18526): warning C4244: '=': conversion from 'int' to 'float', possible loss of data
#   neuralcoref/neuralcoref.cpp(18538): warning C4244: '=': conversion from 'int' to 'float', possible loss of data
#   neuralcoref/neuralcoref.cpp(18550): warning C4244: '=': conversion from 'int' to 'float', possible loss of data
#   neuralcoref/neuralcoref.cpp(18586): warning C4244: '=': conversion from 'double' to 'float', possible loss of data
#   neuralcoref/neuralcoref.cpp(18595): warning C4244: 'argument': conversion from 'uint64_t' to 'int', possible loss of data
#   neuralcoref/neuralcoref.cpp(18622): warning C4244: '=': conversion from 'double' to 'float', possible loss of data
#   neuralcoref/neuralcoref.cpp(18634): warning C4244: '=': conversion from 'int' to 'float', possible loss of data
#   neuralcoref/neuralcoref.cpp(18937): warning C4244: '=': conversion from 'double' to 'float', possible loss of data
#   neuralcoref/neuralcoref.cpp(30715): warning C4244: 'argument': conversion from '__pyx_t_5spacy_8typedefs_attr_t' to 'int', possible loss of data
#   neuralcoref/neuralcoref.cpp(32160): warning C4244: '=': conversion from '__pyx_t_5spacy_8typedefs_attr_t' to 'int', possible loss of data
#   neuralcoref/neuralcoref.cpp(32179): warning C4244: '=': conversion from '__pyx_t_5spacy_8typedefs_attr_t' to 'int', possible loss of data
#   neuralcoref/neuralcoref.cpp(32198): warning C4244: '=': conversion from '__pyx_t_5spacy_8typedefs_attr_t' to 'int', possible loss of data
#   neuralcoref/neuralcoref.cpp(32234): warning C4244: '=': conversion from '__pyx_t_5spacy_8typedefs_attr_t' to 'int', possible loss of data
#   neuralcoref/neuralcoref.cpp(47321): error C2105: '++' needs l-value
#   neuralcoref/neuralcoref.cpp(47323): error C2105: '--' needs l-value
#   neuralcoref/neuralcoref.cpp(47610): error C2105: '++' needs l-value
#   neuralcoref/neuralcoref.cpp(47612): error C2105: '--' needs l-value
#   neuralcoref/neuralcoref.cpp(47849): error C2105: '++' needs l-value
#   neuralcoref/neuralcoref.cpp(47851): error C2105: '--' needs l-value
#   neuralcoref/neuralcoref.cpp(49313): error C2039: 'tp_print': is not a member of '_typeobject'
#   C:\Users\saile\AppData\Local\Programs\Python\Python310\include\cpython/object.h(191): note: see declaration of '_typeobject'
#   neuralcoref/neuralcoref.cpp(49340): error C2039: 'tp_print': is not a member of '_typeobject'
#   C:\Users\saile\AppData\Local\Programs\Python\Python310\include\cpython/object.h(191): note: see declaration of '_typeobject'
#   neuralcoref/neuralcoref.cpp(49346): error C2039: 'tp_print': is not a member of '_typeobject'
#   C:\Users\saile\AppData\Local\Programs\Python\Python310\include\cpython/object.h(191): note: see declaration of '_typeobject'
#   neuralcoref/neuralcoref.cpp(49352): error C2039: 'tp_print': is not a member of '_typeobject'
#   C:\Users\saile\AppData\Local\Programs\Python\Python310\include\cpython/object.h(191): note: see declaration of '_typeobject'
#   neuralcoref/neuralcoref.cpp(49358): error C2039: 'tp_print': is not a member of '_typeobject'
#   C:\Users\saile\AppData\Local\Programs\Python\Python310\include\cpython/object.h(191): note: see declaration of '_typeobject'
#   neuralcoref/neuralcoref.cpp(49364): error C2039: 'tp_print': is not a member of '_typeobject'
#   C:\Users\saile\AppData\Local\Programs\Python\Python310\include\cpython/object.h(191): note: see declaration of '_typeobject'
#   neuralcoref/neuralcoref.cpp(49370): error C2039: 'tp_print': is not a member of '_typeobject'
#   C:\Users\saile\AppData\Local\Programs\Python\Python310\include\cpython/object.h(191): note: see declaration of '_typeobject'
#   neuralcoref/neuralcoref.cpp(49376): error C2039: 'tp_print': is not a member of '_typeobject'
#   C:\Users\saile\AppData\Local\Programs\Python\Python310\include\cpython/object.h(191): note: see declaration of '_typeobject'
#   neuralcoref/neuralcoref.cpp(49382): error C2039: 'tp_print': is not a member of '_typeobject'
#   C:\Users\saile\AppData\Local\Programs\Python\Python310\include\cpython/object.h(191): note: see declaration of '_typeobject'
#   neuralcoref/neuralcoref.cpp(49388): error C2039: 'tp_print': is not a member of '_typeobject'
#   C:\Users\saile\AppData\Local\Programs\Python\Python310\include\cpython/object.h(191): note: see declaration of '_typeobject'
#   neuralcoref/neuralcoref.cpp(49394): error C2039: 'tp_print': is not a member of '_typeobject'
#   C:\Users\saile\AppData\Local\Programs\Python\Python310\include\cpython/object.h(191): note: see declaration of '_typeobject'
#   neuralcoref/neuralcoref.cpp(49400): error C2039: 'tp_print': is not a member of '_typeobject'
#   C:\Users\saile\AppData\Local\Programs\Python\Python310\include\cpython/object.h(191): note: see declaration of '_typeobject'
#   neuralcoref/neuralcoref.cpp(49406): error C2039: 'tp_print': is not a member of '_typeobject'
#   C:\Users\saile\AppData\Local\Programs\Python\Python310\include\cpython/object.h(191): note: see declaration of '_typeobject'
#   neuralcoref/neuralcoref.cpp(49412): error C2039: 'tp_print': is not a member of '_typeobject'
#   C:\Users\saile\AppData\Local\Programs\Python\Python310\include\cpython/object.h(191): note: see declaration of '_typeobject'
#   neuralcoref/neuralcoref.cpp(49418): error C2039: 'tp_print': is not a member of '_typeobject'
#   C:\Users\saile\AppData\Local\Programs\Python\Python310\include\cpython/object.h(191): note: see declaration of '_typeobject'
#   neuralcoref/neuralcoref.cpp(49424): error C2039: 'tp_print': is not a member of '_typeobject'
#   C:\Users\saile\AppData\Local\Programs\Python\Python310\include\cpython/object.h(191): note: see declaration of '_typeobject'
#   neuralcoref/neuralcoref.cpp(49430): error C2039: 'tp_print': is not a member of '_typeobject'
#   C:\Users\saile\AppData\Local\Programs\Python\Python310\include\cpython/object.h(191): note: see declaration of '_typeobject'
#   neuralcoref/neuralcoref.cpp(49436): error C2039: 'tp_print': is not a member of '_typeobject'
#   C:\Users\saile\AppData\Local\Programs\Python\Python310\include\cpython/object.h(191): note: see declaration of '_typeobject'
#   neuralcoref/neuralcoref.cpp(49442): error C2039: 'tp_print': is not a member of '_typeobject'
#   C:\Users\saile\AppData\Local\Programs\Python\Python310\include\cpython/object.h(191): note: see declaration of '_typeobject'
#   neuralcoref/neuralcoref.cpp(49448): error C2039: 'tp_print': is not a member of '_typeobject'
#   C:\Users\saile\AppData\Local\Programs\Python\Python310\include\cpython/object.h(191): note: see declaration of '_typeobject'
#   neuralcoref/neuralcoref.cpp(49456): error C2039: 'tp_print': is not a member of '_typeobject'
#   C:\Users\saile\AppData\Local\Programs\Python\Python310\include\cpython/object.h(191): note: see declaration of '_typeobject'
#   neuralcoref/neuralcoref.cpp(49461): error C2039: 'tp_print': is not a member of '_typeobject'
#   C:\Users\saile\AppData\Local\Programs\Python\Python310\include\cpython/object.h(191): note: see declaration of '_typeobject'
#   neuralcoref/neuralcoref.cpp(49476): error C2039: 'tp_print': is not a member of '_typeobject'
#   C:\Users\saile\AppData\Local\Programs\Python\Python310\include\cpython/object.h(191): note: see declaration of '_typeobject'
#   neuralcoref/neuralcoref.cpp(49489): error C2039: 'tp_print': is not a member of '_typeobject'
#   C:\Users\saile\AppData\Local\Programs\Python\Python310\include\cpython/object.h(191): note: see declaration of '_typeobject'
#   neuralcoref/neuralcoref.cpp(50396): warning C4267: '=': conversion from 'size_t' to 'int', possible loss of data
#   neuralcoref/neuralcoref.cpp(51983): warning C4996: '_PyUnicode_get_wstr_length': deprecated in 3.3
#   neuralcoref/neuralcoref.cpp(51999): warning C4996: '_PyUnicode_get_wstr_length': deprecated in 3.3
#   neuralcoref/neuralcoref.cpp(53921): error C3861: '_PyGen_Send': identifier not found
#   neuralcoref/neuralcoref.cpp(53926): error C3861: '_PyGen_Send': identifier not found
#   neuralcoref/neuralcoref.cpp(54010): error C3861: '_PyGen_Send': identifier not found
#   neuralcoref/neuralcoref.cpp(55241): warning C4996: 'PyUnicode_FromUnicode': deprecated in 3.3
#   error: command 'C:\\Program Files\\Microsoft Visual Studio\\2022\\Community\\VC\\Tools\\MSVC\\14.31.31103\\bin\\HostX86\\x64\\cl.exe' failed with exit code 2
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for neuralcoref
#   error: subprocess-exited-with-error
#
#   Running setup.py install for neuralcoref did not run successfully.
#   exit code: 1
#
#   [114 lines of output]
#   running install
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-3.10
#   creating build\lib.win-amd64-3.10\neuralcoref
#   copying neuralcoref\file_utils.py -> build\lib.win-amd64-3.10\neuralcoref
#   copying neuralcoref\__init__.py -> build\lib.win-amd64-3.10\neuralcoref
#   creating build\lib.win-amd64-3.10\neuralcoref\tests
#   copying neuralcoref\tests\test_neuralcoref.py -> build\lib.win-amd64-3.10\neuralcoref\tests
#   copying neuralcoref\tests\__init__.py -> build\lib.win-amd64-3.10\neuralcoref\tests
#   creating build\lib.win-amd64-3.10\neuralcoref\train
#   copying neuralcoref\train\algorithm.py -> build\lib.win-amd64-3.10\neuralcoref\train
#   copying neuralcoref\train\compat.py -> build\lib.win-amd64-3.10\neuralcoref\train
#   copying neuralcoref\train\conllparser.py -> build\lib.win-amd64-3.10\neuralcoref\train
#   copying neuralcoref\train\dataset.py -> build\lib.win-amd64-3.10\neuralcoref\train
#   copying neuralcoref\train\document.py -> build\lib.win-amd64-3.10\neuralcoref\train
#   copying neuralcoref\train\evaluator.py -> build\lib.win-amd64-3.10\neuralcoref\train
#   copying neuralcoref\train\learn.py -> build\lib.win-amd64-3.10\neuralcoref\train
#   copying neuralcoref\train\model.py -> build\lib.win-amd64-3.10\neuralcoref\train
#   copying neuralcoref\train\utils.py -> build\lib.win-amd64-3.10\neuralcoref\train
#   copying neuralcoref\train\__init__.py -> build\lib.win-amd64-3.10\neuralcoref\train
#   running build_ext
#   building 'neuralcoref.neuralcoref' extension
#   creating build\temp.win-amd64-3.10
#   creating build\temp.win-amd64-3.10\Release
#   creating build\temp.win-amd64-3.10\Release\neuralcoref
#   C:\Program Files\Microsoft Visual Studio\2022\Community\VC\Tools\MSVC\14.31.31103\bin\HostX86\x64\cl.exe /c /nologo /Ox /W3 /GL /DNDEBUG /MD -IC:\Users\saile\AppData\Local\Programs\Python\Python310\include -IC:\Users\saile\AppData\Local\Temp\pip-install-5zugghos\neuralcoref_9fbdf1ae57be4cdc9bb2addfd06aecbe\include -IC:\users\saile\Documents\sailesh\Work\Cognizant\Training\Hands On\venv\include -IC:\Users\saile\AppData\Local\Programs\Python\Python310\include -IC:\Users\saile\AppData\Local\Programs\Python\Python310\Include -IC:\Program Files\Microsoft Visual Studio\2022\Community\VC\Tools\MSVC\14.31.31103\include -IC:\Program Files (x86)\Windows Kits\10\include\10.0.19041.0\ucrt -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.19041.0\\shared -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.19041.0\\um -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.19041.0\\winrt -IC:\Program Files (x86)\Windows Kits\10\\include\10.0.19041.0\\cppwinrt /EHsc /Tpneuralcoref/neuralcoref.cpp /Fobuild\temp.win-amd64-3.10\Release\neuralcoref/neuralcoref.obj /Ox /EHsc
#   neuralcoref.cpp
#   C:\Users\saile\AppData\Local\Temp\pip-install-5zugghos\neuralcoref_9fbdf1ae57be4cdc9bb2addfd06aecbe\include\numpy\npy_deprecated_api.h(8) : Warning Msg: Using deprecated NumPy API, disable it by #defining NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION
#   neuralcoref/neuralcoref.cpp(6050): warning C4244: '=': conversion from 'Py_ssize_t' to 'int', possible loss of data
#   neuralcoref/neuralcoref.cpp(6904): warning C4244: '=': conversion from 'double' to 'float', possible loss of data
#   neuralcoref/neuralcoref.cpp(8989): warning C4018: '>': signed/unsigned mismatch
#   neuralcoref/neuralcoref.cpp(9046): warning C4018: '<': signed/unsigned mismatch
#   neuralcoref/neuralcoref.cpp(10177): warning C4244: '=': conversion from 'Py_ssize_t' to 'int', possible loss of data
#   neuralcoref/neuralcoref.cpp(10252): warning C4244: '=': conversion from 'Py_ssize_t' to 'int', possible loss of data
#   neuralcoref/neuralcoref.cpp(17150): warning C4244: '=': conversion from 'Py_ssize_t' to 'int', possible loss of data
#   neuralcoref/neuralcoref.cpp(18283): warning C4244: 'argument': conversion from 'uint64_t' to 'int', possible loss of data
#   neuralcoref/neuralcoref.cpp(18283): warning C4244: 'argument': conversion from 'uint64_t' to 'int', possible loss of data
#   neuralcoref/neuralcoref.cpp(18526): warning C4244: '=': conversion from 'int' to 'float', possible loss of data
#   neuralcoref/neuralcoref.cpp(18538): warning C4244: '=': conversion from 'int' to 'float', possible loss of data
#   neuralcoref/neuralcoref.cpp(18550): warning C4244: '=': conversion from 'int' to 'float', possible loss of data
#   neuralcoref/neuralcoref.cpp(18586): warning C4244: '=': conversion from 'double' to 'float', possible loss of data
#   neuralcoref/neuralcoref.cpp(18595): warning C4244: 'argument': conversion from 'uint64_t' to 'int', possible loss of data
#   neuralcoref/neuralcoref.cpp(18622): warning C4244: '=': conversion from 'double' to 'float', possible loss of data
#   neuralcoref/neuralcoref.cpp(18634): warning C4244: '=': conversion from 'int' to 'float', possible loss of data
#   neuralcoref/neuralcoref.cpp(18937): warning C4244: '=': conversion from 'double' to 'float', possible loss of data
#   neuralcoref/neuralcoref.cpp(30715): warning C4244: 'argument': conversion from '__pyx_t_5spacy_8typedefs_attr_t' to 'int', possible loss of data
#   neuralcoref/neuralcoref.cpp(32160): warning C4244: '=': conversion from '__pyx_t_5spacy_8typedefs_attr_t' to 'int', possible loss of data
#   neuralcoref/neuralcoref.cpp(32179): warning C4244: '=': conversion from '__pyx_t_5spacy_8typedefs_attr_t' to 'int', possible loss of data
#   neuralcoref/neuralcoref.cpp(32198): warning C4244: '=': conversion from '__pyx_t_5spacy_8typedefs_attr_t' to 'int', possible loss of data
#   neuralcoref/neuralcoref.cpp(32234): warning C4244: '=': conversion from '__pyx_t_5spacy_8typedefs_attr_t' to 'int', possible loss of data
#   neuralcoref/neuralcoref.cpp(47321): error C2105: '++' needs l-value
#   neuralcoref/neuralcoref.cpp(47323): error C2105: '--' needs l-value
#   neuralcoref/neuralcoref.cpp(47610): error C2105: '++' needs l-value
#   neuralcoref/neuralcoref.cpp(47612): error C2105: '--' needs l-value
#   neuralcoref/neuralcoref.cpp(47849): error C2105: '++' needs l-value
#   neuralcoref/neuralcoref.cpp(47851): error C2105: '--' needs l-value
#   neuralcoref/neuralcoref.cpp(49313): error C2039: 'tp_print': is not a member of '_typeobject'
#   C:\Users\saile\AppData\Local\Programs\Python\Python310\include\cpython/object.h(191): note: see declaration of '_typeobject'
#   neuralcoref/neuralcoref.cpp(49340): error C2039: 'tp_print': is not a member of '_typeobject'
#   C:\Users\saile\AppData\Local\Programs\Python\Python310\include\cpython/object.h(191): note: see declaration of '_typeobject'
#   neuralcoref/neuralcoref.cpp(49346): error C2039: 'tp_print': is not a member of '_typeobject'
#   C:\Users\saile\AppData\Local\Programs\Python\Python310\include\cpython/object.h(191): note: see declaration of '_typeobject'
#   neuralcoref/neuralcoref.cpp(49352): error C2039: 'tp_print': is not a member of '_typeobject'
#   C:\Users\saile\AppData\Local\Programs\Python\Python310\include\cpython/object.h(191): note: see declaration of '_typeobject'
#   neuralcoref/neuralcoref.cpp(49358): error C2039: 'tp_print': is not a member of '_typeobject'
#   C:\Users\saile\AppData\Local\Programs\Python\Python310\include\cpython/object.h(191): note: see declaration of '_typeobject'
#   neuralcoref/neuralcoref.cpp(49364): error C2039: 'tp_print': is not a member of '_typeobject'
#   C:\Users\saile\AppData\Local\Programs\Python\Python310\include\cpython/object.h(191): note: see declaration of '_typeobject'
#   neuralcoref/neuralcoref.cpp(49370): error C2039: 'tp_print': is not a member of '_typeobject'
#   C:\Users\saile\AppData\Local\Programs\Python\Python310\include\cpython/object.h(191): note: see declaration of '_typeobject'
#   neuralcoref/neuralcoref.cpp(49376): error C2039: 'tp_print': is not a member of '_typeobject'
#   C:\Users\saile\AppData\Local\Programs\Python\Python310\include\cpython/object.h(191): note: see declaration of '_typeobject'
#   neuralcoref/neuralcoref.cpp(49382): error C2039: 'tp_print': is not a member of '_typeobject'
#   C:\Users\saile\AppData\Local\Programs\Python\Python310\include\cpython/object.h(191): note: see declaration of '_typeobject'
#   neuralcoref/neuralcoref.cpp(49388): error C2039: 'tp_print': is not a member of '_typeobject'
#   C:\Users\saile\AppData\Local\Programs\Python\Python310\include\cpython/object.h(191): note: see declaration of '_typeobject'
#   neuralcoref/neuralcoref.cpp(49394): error C2039: 'tp_print': is not a member of '_typeobject'
#   C:\Users\saile\AppData\Local\Programs\Python\Python310\include\cpython/object.h(191): note: see declaration of '_typeobject'
#   neuralcoref/neuralcoref.cpp(49400): error C2039: 'tp_print': is not a member of '_typeobject'
#   C:\Users\saile\AppData\Local\Programs\Python\Python310\include\cpython/object.h(191): note: see declaration of '_typeobject'
#   neuralcoref/neuralcoref.cpp(49406): error C2039: 'tp_print': is not a member of '_typeobject'
#   C:\Users\saile\AppData\Local\Programs\Python\Python310\include\cpython/object.h(191): note: see declaration of '_typeobject'
#   neuralcoref/neuralcoref.cpp(49412): error C2039: 'tp_print': is not a member of '_typeobject'
#   C:\Users\saile\AppData\Local\Programs\Python\Python310\include\cpython/object.h(191): note: see declaration of '_typeobject'
#   neuralcoref/neuralcoref.cpp(49418): error C2039: 'tp_print': is not a member of '_typeobject'
#   C:\Users\saile\AppData\Local\Programs\Python\Python310\include\cpython/object.h(191): note: see declaration of '_typeobject'
#   neuralcoref/neuralcoref.cpp(49424): error C2039: 'tp_print': is not a member of '_typeobject'
#   C:\Users\saile\AppData\Local\Programs\Python\Python310\include\cpython/object.h(191): note: see declaration of '_typeobject'
#   neuralcoref/neuralcoref.cpp(49430): error C2039: 'tp_print': is not a member of '_typeobject'
#   C:\Users\saile\AppData\Local\Programs\Python\Python310\include\cpython/object.h(191): note: see declaration of '_typeobject'
#   neuralcoref/neuralcoref.cpp(49436): error C2039: 'tp_print': is not a member of '_typeobject'
#   C:\Users\saile\AppData\Local\Programs\Python\Python310\include\cpython/object.h(191): note: see declaration of '_typeobject'
#   neuralcoref/neuralcoref.cpp(49442): error C2039: 'tp_print': is not a member of '_typeobject'
#   C:\Users\saile\AppData\Local\Programs\Python\Python310\include\cpython/object.h(191): note: see declaration of '_typeobject'
#   neuralcoref/neuralcoref.cpp(49448): error C2039: 'tp_print': is not a member of '_typeobject'
#   C:\Users\saile\AppData\Local\Programs\Python\Python310\include\cpython/object.h(191): note: see declaration of '_typeobject'
#   neuralcoref/neuralcoref.cpp(49456): error C2039: 'tp_print': is not a member of '_typeobject'
#   C:\Users\saile\AppData\Local\Programs\Python\Python310\include\cpython/object.h(191): note: see declaration of '_typeobject'
#   neuralcoref/neuralcoref.cpp(49461): error C2039: 'tp_print': is not a member of '_typeobject'
#   C:\Users\saile\AppData\Local\Programs\Python\Python310\include\cpython/object.h(191): note: see declaration of '_typeobject'
#   neuralcoref/neuralcoref.cpp(49476): error C2039: 'tp_print': is not a member of '_typeobject'
#   C:\Users\saile\AppData\Local\Programs\Python\Python310\include\cpython/object.h(191): note: see declaration of '_typeobject'
#   neuralcoref/neuralcoref.cpp(49489): error C2039: 'tp_print': is not a member of '_typeobject'
#   C:\Users\saile\AppData\Local\Programs\Python\Python310\include\cpython/object.h(191): note: see declaration of '_typeobject'
#   neuralcoref/neuralcoref.cpp(50396): warning C4267: '=': conversion from 'size_t' to 'int', possible loss of data
#   neuralcoref/neuralcoref.cpp(51983): warning C4996: '_PyUnicode_get_wstr_length': deprecated in 3.3
#   neuralcoref/neuralcoref.cpp(51999): warning C4996: '_PyUnicode_get_wstr_length': deprecated in 3.3
#   neuralcoref/neuralcoref.cpp(53921): error C3861: '_PyGen_Send': identifier not found
#   neuralcoref/neuralcoref.cpp(53926): error C3861: '_PyGen_Send': identifier not found
#   neuralcoref/neuralcoref.cpp(54010): error C3861: '_PyGen_Send': identifier not found
#   neuralcoref/neuralcoref.cpp(55241): warning C4996: 'PyUnicode_FromUnicode': deprecated in 3.3
#   error: command 'C:\\Program Files\\Microsoft Visual Studio\\2022\\Community\\VC\\Tools\\MSVC\\14.31.31103\\bin\\HostX86\\x64\\cl.exe' failed with exit code 2
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: legacy-install-failure
#
# Encountered error while trying to install package.
#
# neuralcoref
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for output from the failure.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <cell line: 3>()
#       1 get_ipython().system('pip install neuralcoref')
# ----> 3 import neuralcoref
#       5 newnlp = spacy.load('en_core_web_lg')
#       6 neuralcoref.add_to_pipe(newnlp)
#
# ModuleNotFoundError: No module named 'neuralcoref'
